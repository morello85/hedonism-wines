# %%
## HED00089
## https://hedonism.co.uk/product/springbank-24-year-old-single-cask-uk-customers-1994-whisky

# %%
# Objective

# 1. Removing duplicates from the stocks table
# --- Check row count by import date
# --- Identify duplicates and de-duplicate them by averaging availability, use stocks_table schema
# --- Export new_28_df to correct_rows_2024_03_28.csv
# --- Delete the relevant codes from the stocks table

# 2. Re-creating the csv file of 2024-03-28 so it doesn't contain duplicates
# --- Insert the new correct_rows_2024_03_28.csv with the de-duplicated rows into the stocks table
# --- Export the stocks table for the 28th into its own CSV, remember to use the original schema and column names
# --- UPDATE import_dates
# --- Check URLs have been populated by the main.py process

# %%
import pandas as pd
from sqlalchemy import create_engine
import duckdb


# Specify the file path for the DuckDB database
db_path = '/Users/MacUser/hedonism-wines_fresh/database.db'  # Example path, replace with your desired path

# Establish a connection to an in-memory DuckDB database
conn = duckdb.connect(database=db_path, read_only=False)

# %%
	results = conn.execute("""
                       WITH todays_items AS (             
                        SELECT code, title, url, price_gbp, availability, import_date 
                        FROM whisky_stocks_table
                        WHERE import_date = CURRENT_DATE()
                       ),
                       yesterdays_items AS (
                        SELECT code, title, url, price_gbp, availability, import_date  
                        FROM whisky_stocks_table
                        WHERE import_date = CURRENT_DATE() -1
                       )
                       SELECT CAST(CURRENT_DATE() AS DATE) AS import_date, a.code,
						a.title, 
						a.url, 
						a.price_gbp,
						a.today_availability availability,
                        CAST(a.yesterday_availability AS FLOAT) - CAST(a.today_availability AS FLOAT) units_sold
                       FROM 
                       (
                       SELECT 
                       CAST (y.code AS STRING) ||'-'|| CAST (y.availability AS STRING) yesterday_code_availability,
                       CAST (t.code AS STRING) ||'-'|| CAST (t.availability AS STRING) today_code_availability,
                       y.code,
                       y.title,
                       y.url,
                       y.price_gbp,
                       y.availability yesterday_availability,
                       t.availability today_availability
                       FROM yesterdays_items y LEFT OUTER JOIN todays_items t
                       ON y.code = t.code
                       ) a
                       WHERE a.today_code_availability <> yesterday_code_availability
					   AND CAST(a.yesterday_availability AS FLOAT) - CAST(a.today_availability AS FLOAT) > 0
                       ORDER BY price_gbp DESC
						    """).fetchdf()

	# Convert the results to a DataFrame
	df = pd.DataFrame(results)
df
# Out:
#    import_date      code                                              title  \
# 0   2025-01-07  HED89678               Macallan 18 Year Old Sherry Oak 1997
# 1   2025-01-07  HED00263  Glenfarclas 24 Year Old Millennium Cask (Third...
# 2   2025-01-07   HED3140                                Bowmore 25 Year Old
# 3   2025-01-07  HED40141                   Macallan 18 Year Old Double Cask
# 4   2025-01-07  HED69377                  Hazelburn 10 Year Old Single Cask
# 5   2025-01-07  HED79481                  Daftmill Winter Distillation 2007
# 6   2025-01-07  HED21889  Bladnoch 23 Year Old Fresh Amontillado Cask (E...
# 7   2025-01-07  HED47173         Springbank 12 Year Old Cask Strength 57.2%
# 8   2025-01-07  HED00230      Bladnoch 22 Year Old Canasta Sherry Butt 2001
# 9   2025-01-07   HED3110                      Balvenie 21 Year Old Portwood
# 10  2025-01-07   HED4505                              Glengoyne 21 Year Old
# 11  2025-01-07  HED21064  Speyside 18 Year Old (M) Cask Strength Collect...
# 12  2025-01-07  HED14607                            Glenfarclas 25 Year Old
# 13  2025-01-07  HED01824  Arran 19 Year Old Private Cask (Exclusive to H...
# 14  2025-01-07  HED47364                            Glendronach 18 Year Old
# 15  2025-01-07   HED3161                               Yamazaki 12 Year Old
# 16  2025-01-07  HED64374                           Bunnahabhain 18 Year Old
# 17  2025-01-07  HED45869                    Balvenie 16 Year Old French Oak
# 18  2025-01-07  HED46862                Macallan Classic Cut (2022 Release)
# 19  2025-01-07  HED81828                              Glengoyne 18 Year Old
# 20  2025-01-07  HED46953                Macallan Classic Cut (2023 Release)
# 21  2025-01-07   HED6068                              Glenlivet 18 Year Old
# 22  2025-01-07  HED69170                   Macallan 12 Year Old Triple Cask
# 23  2025-01-07  HED69073                               Deanston 18 Year Old
# 24  2025-01-07   HED7560                         Kavalan King Car Conductor
# 25  2025-01-07   HED2976                    Macallan 12 Year Old Sherry Oak
# 26  2025-01-07  HED00044  Isle of Raasay Oloroso Sherry Quarter Cask (Ex...
# 27  2025-01-07  HED46820       Lakes Distillery Whiskymaker`s Reserve No. 7
# 28  2025-01-07  HED70117                            Hibiki Japanese Harmony
# 29  2025-01-07  HED51274                            Glendronach 15 Year Old
# 30  2025-01-07  HED47252              Glenturret 12 Year Old (2024 Release)
# 31  2025-01-07  HED14691                      Glenfarclas 105 Cask Strength
# 32  2025-01-07  HED40295                           GlenAllachie 15 Year Old
# 33  2025-01-07  HED21944              Ardnahoe 5 Year Old Inaugural Release
# 34  2025-01-07  HED47100                         Lindores Abbey Sherry Cask
# 35  2025-01-07   HED7661                                 Nikka Coffey Grain
# 36  2025-01-07  HED82200                            Glenfiddich 15 Year Old
# 37  2025-01-07  HED45872   Balvenie 12 Year Old Sweet Toast of American Oak
# 38  2025-01-07  HED45814                  Lindores Abbey STR Wine Barriques
# 39  2025-01-07  HED63421                             Port Askaig 8 Year Old
# 40  2025-01-07   HED2903                              Nikka From The Barrel
# 41  2025-01-07   HED6066                              Glenlivet 12 Year Old
# 42  2025-01-07  HED46704                             Maclean`s Nose Adelphi
# 43  2025-01-07  HED10534                        Johnnie Walker Double Black
# 44  2025-01-07  HED46784                   Lochlea Harvest Edition 2nd Crop
# 45  2025-01-07   HED6042             Johnnie Walker Black Label 12 Year Old
#
#                                                   url  price_gbp availability  \
# 0   https://hedonism.co.uk/product/macallan-18-yea...     1200.0          2.0
# 1   https://hedonism.co.uk/product/glenfarclas-24-...      510.0         17.0
# 2   https://hedonism.co.uk/product/bowmore-25-year...      450.0          3.0
# 3   https://hedonism.co.uk/product/macallan-18-yea...      310.0         32.0
# 4   https://hedonism.co.uk/product/hazelburn-10-ye...      295.0          3.0
# 5   https://hedonism.co.uk/product/daftmill-winter...      295.0          1.0
# 6   https://hedonism.co.uk/product/bladnoch-23-yea...      295.0        229.0
# 7   https://hedonism.co.uk/product/springbank-12-y...      275.0         15.0
# 8   https://hedonism.co.uk/product/bladnoch-22-yea...      250.0          1.0
# 9   https://hedonism.co.uk/product/balvenie-21-yea...      243.0         12.0
# 10  https://hedonism.co.uk/product/glengoyne-21-ye...      225.0         20.0
# 11  https://hedonism.co.uk/product/speyside-18-yea...      212.0         11.0
# 12  https://hedonism.co.uk/product/glenfarclas-25-...      195.0         38.0
# 13  https://hedonism.co.uk/product/arran-19-year-o...      185.0        150.0
# 14  https://hedonism.co.uk/product/glendronach-18-...      179.0          7.0
# 15  https://hedonism.co.uk/product/yamazaki-12-yea...      145.0         66.0
# 16  https://hedonism.co.uk/product/bunnahabhain-18...      141.0         32.0
# 17  https://hedonism.co.uk/product/balvenie-16-yea...      130.0         24.0
# 18  https://hedonism.co.uk/product/macallan-classi...      125.0          4.0
# 19  https://hedonism.co.uk/product/glengoyne-18-ye...      115.0         36.0
# 20  https://hedonism.co.uk/product/macallan-classi...      115.0         15.0
# 21  https://hedonism.co.uk/product/glenlivet-18-ye...      105.0          4.0
# 22  https://hedonism.co.uk/product/macallan-12-yea...      100.0         15.0
# 23  https://hedonism.co.uk/product/deanston-18-yea...       90.0          5.0
# 24  https://hedonism.co.uk/product/kavalan-king-ca...       86.5          4.0
# 25  https://hedonism.co.uk/product/macallan-12-yea...       86.0         35.0
# 26  https://hedonism.co.uk/product/isle-raasay-olo...       85.0         56.0
# 27  https://hedonism.co.uk/product/lakes-distiller...       84.9          2.0
# 28  https://hedonism.co.uk/product/hibiki-japanese...       81.0         80.0
# 29  https://hedonism.co.uk/product/glendronach-15-...       78.5         12.0
# 30  https://hedonism.co.uk/product/glenturret-12-y...       77.0          1.0
# 31  https://hedonism.co.uk/product/glenfarclas-105...       73.0         35.0
# 32  https://hedonism.co.uk/product/glenallachie-15...       71.0         11.0
# 33  https://hedonism.co.uk/product/ardnahoe-5-year...       70.0         27.0
# 34  https://hedonism.co.uk/product/lindores-abbey-...       60.0          2.0
# 35  https://hedonism.co.uk/product/nikka-coffey-gr...       58.9          8.0
# 36  https://hedonism.co.uk/product/glenfiddich-15-...       56.0          7.0
# 37  https://hedonism.co.uk/product/balvenie-12-yea...       56.0          5.0
# 38  https://hedonism.co.uk/product/lindores-abbey-...       52.5          1.0
# 39  https://hedonism.co.uk/product/port-askaig-8-y...       50.0          4.0
# 40  https://hedonism.co.uk/product/nikka-barrel-wh...       45.9         16.0
# 41  https://hedonism.co.uk/product/glenlivet-12-ye...       45.0         23.0
# 42  https://hedonism.co.uk/product/macleans-nose-a...       38.0          1.0
# 43  https://hedonism.co.uk/product/johnnie-walker-...       37.5          8.0
# 44  https://hedonism.co.uk/product/lochlea-harvest...       35.0          8.0
# 45  https://hedonism.co.uk/product/johnnie-walker-...       28.9         42.0
#
#     units_sold
# 0          1.0
# 1          1.0
# 2          2.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          3.0
# 7          1.0
# 8          1.0
# 9          6.0
# 10         2.0
# 11         2.0
# 12         3.0
# 13         2.0
# 14         3.0
# 15         6.0
# 16         2.0
# 17         3.0
# 18         3.0
# 19         3.0
# 20         2.0
# 21         1.0
# 22         1.0
# 23         2.0
# 24         2.0
# 25         1.0
# 26         6.0
# 27         2.0
# 28         4.0
# 29         1.0
# 30         3.0
# 31         2.0
# 32         2.0
# 33         1.0
# 34         2.0
# 35         1.0
# 36         4.0
# 37         2.0
# 38         2.0
# 39         1.0
# 40         2.0
# 41         1.0
# 42         2.0
# 43         3.0
# 44         2.0
# 45         1.0

# %%
    # Get today's date
from datetime import datetime

today_date_file_name = datetime.now().strftime("_%Y_%m_%d")

    # Define filename with today's date appended
filename = f"sales{today_date_file_name}.csv"  # Change "data" to your desired filename prefix
        
    # Define the path where you want to save the file
folder_path = "/Users/MacUser/hedonism-wines_fresh/sales_data"  # Change this to your desired folder path


	
    
    # Export dataframe
df.to_csv(folder_path + filename, index=False)

	# Convert import_date to datetime
df['import_date'] = pd.to_datetime(df['import_date'])

	# Extract date part
df['import_date'] = df['import_date'].dt.date
df['import_date'] = df['import_date'].astype(str).str[:10]
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
	results = conn.execute("""
                       WITH todays_items AS (             
                        SELECT code, title, url, price_gbp, availability, import_date 
                        FROM whisky_stocks_table
                        WHERE import_date = CURRENT_DATE()
                       ),
                       yesterdays_items AS (
                        SELECT code, title, url, price_gbp, availability, import_date  
                        FROM whisky_stocks_table
                        WHERE import_date = CURRENT_DATE() -1
                       )
                       SELECT CAST(CURRENT_DATE() AS DATE) AS import_date, a.code,
						a.title, 
						a.url, 
						a.price_gbp,
						a.today_availability availability,
                        CAST(a.yesterday_availability AS FLOAT) - CAST(a.today_availability AS FLOAT) units_sold
                       FROM 
                       (
                       SELECT 
                       CAST (y.code AS STRING) ||'-'|| CAST (y.availability AS STRING) yesterday_code_availability,
                       CAST (t.code AS STRING) ||'-'|| CAST (t.availability AS STRING) today_code_availability,
                       y.code,
                       y.title,
                       y.url,
                       y.price_gbp,
                       y.availability yesterday_availability,
                       t.availability today_availability
                       FROM yesterdays_items y LEFT OUTER JOIN todays_items t
                       ON y.code = t.code
                       ) a
                       WHERE a.today_code_availability <> yesterday_code_availability
					   AND CAST(a.yesterday_availability AS FLOAT) - CAST(a.today_availability AS FLOAT) > 0
                       ORDER BY price_gbp DESC
                """).fetchdf()

	# Convert the results to a DataFrame
	df = pd.DataFrame(results)

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [import_date, code, title, url, price_gbp, availability, units_sold]
# Index: []

# %%
# 1. Check row count by import date
results = conn.execute("""                
                        SELECT price_gbp, price_incl_vat,
                       COALESCE(price_gbp, price_incl_vat) AS price_gbp,
                       COALESCE(price_incl_vat, 0) price_incl_vat
                       FROM whisky_stocks_table WHERE price_incl_vat IS NULL
            """).fetchdf()
	# Convert the results to a DataFrame
df = pd.DataFrame(results)
df.head()
# Out:
#    price_gbp  price_incl_vat  price_gbp_1  price_incl_vat_1
# 0      520.0             NaN        520.0               0.0
# 1     2400.0             NaN       2400.0               0.0
# 2     7250.0             NaN       7250.0               0.0
# 3      195.0             NaN        195.0               0.0
# 4     4895.0             NaN       4895.0               0.0
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df['title'] = df['title'].str.replace("`",'')

# %%
df['title']
# Out:
# 0                           Lossit Archivists Selection
# 1                                  Ichiros Malt & Grain
# 2                  Ushers Old Vatted Glenlivet c. 1920s
# 3                               Borderers Blend c. 1910
# 4                               Bowmore Devils Cask III
#                             ...
# 71           Lagavulin Distillers Edition LG.4/490 1986
# 72    Balvenie 15 Year Old Craftsmans Reserve No.1 C...
# 73           Lagavulin Distillers Edition LG.4/501 1995
# 74    Unnamed Islay (LA) 31 Year Old Symingtons Choi...
# 75    Dalmore 16 Year Old Luminary No.2 2024 Edition...
# Name: title, Length: 76, dtype: object

# %%
df['title'].head(30)
# Out:
# 0                           Lossit Archivists Selection
# 1                                  Ichiros Malt & Grain
# 2                  Ushers Old Vatted Glenlivet c. 1920s
# 3                               Borderers Blend c. 1910
# 4                               Bowmore Devils Cask III
# 5                               Ballantines 40 Year Old
# 6                            Glenlivet Founders Reserve
# 7                   Ichiros Malt Hanyu 15 Year Old 2000
# 8     Bowmore 42 Year Old Black The Trilogy Edition ...
# 9     Ardbeg 22 Year Old Managers Choice Sherry Butt...
# 10                                     Ichiros Malt MWR
# 11                       Ichiros Malt Wine Wood Reserve
# 12                                      Tomintoul TLath
# 13                  Knockando 12 Year Old Managers Dram
# 14                           Bains Cape Mountain Whisky
# 15             Teaninich 17 Year Old Managers Dram 2001
# 16     Ichiros Malt Hanyu Ten Diamonds 21 Year Old 1990
# 17                                  Bowmore Devils Cask
# 18            Royal Lochnagar 10 Year Old Managers Dram
# 19                               Bowmore Devils Cask II
# 20                             Ichiros Malt Hanyu Joker
# 21                             Chita Distillers Reserve
# 22                               Hibiki Blenders Choice
# 23                             Ichiros Malt & Grain 505
# 24            Ichiros Malt & Grain 2020 Limited Edition
# 25        Lagavulin Managers Choice (Bottled 2009) 1993
# 26               Ichiros Malt Hanyu Seven Diamonds 1991
# 27                  Ichiros Malt Hanyu Eight Clubs 1988
# 28       Yamazaki 18 Year Old Owners Cask Hogshead 1991
# 29                        Glen Garioch Founders Reserve
# Name: title, dtype: object

# %%
import re

def remove_punctuation(text):
    # Define a regular expression pattern to match punctuation characters
    punctuation_pattern = r'[^\w\s]'
    
    # Use re.sub() to replace all punctuation characters with an empty string
    clean_text = re.sub(punctuation_pattern, '', text)
    
    return clean_text

# Example usage:
#text_with_punctuation = "Hello, world! How are you doing today?"
#clean_text = remove_punctuation(text_with_punctuation)
#print(clean_text)
df['title'] = df['title'].apply(remove_punctuation)

# %%
df['title']
# Out:
# 0                           Lossit Archivists Selection
# 1                                   Ichiros Malt  Grain
# 2                   Ushers Old Vatted Glenlivet c 1920s
# 3                                Borderers Blend c 1910
# 4                               Bowmore Devils Cask III
#                             ...
# 71             Lagavulin Distillers Edition LG4490 1986
# 72    Balvenie 15 Year Old Craftsmans Reserve No1 Co...
# 73             Lagavulin Distillers Edition LG4501 1995
# 74    Unnamed Islay LA 31 Year Old Symingtons Choice...
# 75    Dalmore 16 Year Old Luminary No2 2024 Edition ...
# Name: title, Length: 76, dtype: object
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# 2. Identify duplicates and de-duplicate them by averaging availability
results = conn.execute("""                
                        WITH duplicates as (
                                              SELECT COUNT (*) duplicate_count, code	  
                                            FROM stocks_table
                                            WHERE import_date = '2024-03-28'
                                            GROUP BY code
                                            HAVING COUNT (*) > 1)
                       SELECT 
                       s.code, --Code
                       s.title, -- Title
                       s.size, -- Size
                       s.style, --Style
                       s.country, --Country
                       s.type, --Group
                       ROUND(AVG(s.availability),0) availability, --Available
                       AVG(s.price_gbp) price_gbp --"Price (GBP)"
                       FROM stocks_table s JOIN duplicates d on s.code = d.code
                       WHERE import_date = '2024-03-28'
                       GROUP BY 
                      s.code,
                       s.title,
                       s.size,
                       s.style,
                       s.country,
                       s.type
            """).fetchdf()
	# Convert the results to a DataFrame
new_28_df = pd.DataFrame(results)
new_28_df
# Out:
#           code                                         title    size    style  \
# 0      HED0112                     Highland Park 18 Year Old    70cl  Spirits
# 1      HED0544                       Leoville Las Cases 2005    75cl      Red
# 2      HED0581                                  Margaux 2005    75cl      Red
# 3      HED0699                                   Petrus 1995    75cl      Red
# 4      HED1798                      Krug Clos du Mesnil 2000    75cl    White
# ...        ...                                           ...     ...      ...
# 2616  HED87539                            Rieussec Half 2007  37.5cl    White
# 2617  HED21088             Sheringham Distillery Seaside Gin    70cl  Spirits
# 2618  HED96656  Puligny Montrachet Champs Gains Borgeot 2002    75cl    White
# 2619  HED24318    Von Buhl Riesling Bone Dry QbA Magnum 2022   150cl    White
# 2620  HED95819                              Coutet Half 1989  37.5cl    White
#
#        country                type  availability    price_gbp
# 0     Scotland              Whisky          12.0   125.000000
# 1       France            Bordeaux           3.0   340.000000
# 2       France            Bordeaux          10.0  1050.000000
# 3       France            Bordeaux          20.0  4980.000000
# 4       France           Champagne           5.0  1380.000000
# ...        ...                 ...           ...          ...
# 2616    France  Sauternes & Barsac           5.0    40.000000
# 2617    Canada                 Gin           2.0    38.900002
# 2618    France            Burgundy           2.0    72.099998
# 2619   Germany             Germany           6.0    40.900002
# 2620    France  Sauternes & Barsac           4.0    49.900002
#
# [2621 rows x 8 columns]

# %%
# 3. Export correct list of previously duplicated ids into their own dataset
new_28_df.to_csv('/Users/MacUser/hedonism-wines_app/correct_rows_2024_03_28.csv',index=False)

# %%
# 4. Execute DELETE queries and commit the changes
delete_query_1 = f"""

                        WITH duplicates as (
                                              SELECT COUNT (*) duplicate_count, code	  
                                            FROM stocks_table
                                            WHERE import_date = '2024-03-28'
                                            GROUP BY code
                                            HAVING COUNT (*) > 1),
                       main AS (
                       SELECT 
                       s.code, --Code
                       s.title, -- Title
                       s.size, -- Size
                       s.style, --Style
                       s.country, --Country
                       s.type, --Group
                       ROUND(AVG(s.availability),0) availability, --Available
                       AVG(s.price_gbp) price_gbp --"Price (GBP)"
                       FROM stocks_table s JOIN duplicates d on s.code = d.code
                       WHERE import_date = '2024-03-28'
                       GROUP BY 
                      s.code,
                       s.title,
                       s.size,
                       s.style,
                       s.country,
                       s.type)
                    DELETE FROM 
                    stocks_table 
                    WHERE import_date = '2024-03-28'
                    AND code IN (
                        SELECT code from main)
                        """
conn.execute(delete_query_1)

# %%
conn.commit()

# %%
# 5. Reimport the cleaned rows back into the main table
df=pd.read_csv('/Users/MacUser/hedonism-wines_app/correct_rows_2024_03_28.csv')
df.head()
# Out:
#       code                      title  size    style   country       type  \
# 0  HED0112  Highland Park 18 Year Old  70cl  Spirits  Scotland     Whisky
# 1  HED0544    Leoville Las Cases 2005  75cl      Red    France   Bordeaux
# 2  HED0581               Margaux 2005  75cl      Red    France   Bordeaux
# 3  HED0699                Petrus 1995  75cl      Red    France   Bordeaux
# 4  HED1798   Krug Clos du Mesnil 2000  75cl    White    France  Champagne
#
#    availability  price_gbp
# 0          12.0      125.0
# 1           3.0      340.0
# 2          10.0     1050.0
# 3          20.0     4980.0
# 4           5.0     1380.0

# %%
    # Get the column names from the DataFrame
columns = list(df.columns)

    # Generate the list of column names for the INSERT INTO statement
column_names = ", ".join(columns)

    # Generate the list of parameter placeholders (?, ?, ?) for the VALUES clause
parameter_placeholders = ", ".join(["?" for _ in range(len(columns))])

    # Convert the DataFrame to records list
records = df.values.tolist()

    # Define the name of your existing table
table_name = 'stocks_table'

    # Construct the SQL INSERT INTO statement dynamically
sql_insert = f"INSERT INTO {table_name} ({column_names}) VALUES ({parameter_placeholders})"

    # Execute the INSERT statement
conn.executemany(sql_insert, records)

# %%
# Execute UPDATE queries to fix null import_dates
import_date_update_query = f"""
                        UPDATE stocks_table
                        SET import_date = '2024-03-28'
                        WHERE import_date IS NULL
                        """
conn.execute(import_date_update_query)

# %%
conn.commit()

# %%
# 2. Identify duplicates and de-duplicate them by averaging availability
results = conn.execute("""                
                       SELECT
                      s.code Code,
                      s.title Title,
                      s.size Size,
                      s.style Style,
                      s.country Country,
                      s.type AS Group,
                      s.availability Available,
                      s.price_gbp "Price (GBP)"
                       FROM stocks_table s
                       WHERE import_date = '2024-03-28'
            """).fetchdf()
	# Convert the results to a DataFrame
df = pd.DataFrame(results)
df
# Out:
#            Code                                         Title    Size  \
# 0       HED0037                                    Louis XIII    70cl
# 1       HED0059                            Ardbeg 17 Year Old    70cl
# 2       HED0062                      Ardbeg Lord of the Isles    70cl
# 3       HED0068                          Balvenie 40 Year Old    70cl
# 4       HED0097       Glenfiddich 40 Year Old Cumulative Time    70cl
# ...         ...                                           ...     ...
# 10798  HED87539                            Rieussec Half 2007  37.5cl
# 10799  HED21088             Sheringham Distillery Seaside Gin    70cl
# 10800  HED96656  Puligny Montrachet Champs Gains Borgeot 2002    75cl
# 10801  HED24318    Von Buhl Riesling Bone Dry QbA Magnum 2022   150cl
# 10802  HED95819                              Coutet Half 1989  37.5cl
#
#          Style   Country               Group  Available  Price (GBP)
# 0      Spirits    France              Cognac        4.0  2950.000000
# 1      Spirits  Scotland              Whisky        2.0   595.000000
# 2      Spirits  Scotland              Whisky        2.0  2400.000000
# 3      Spirits  Scotland              Whisky        4.0  7250.000000
# 4      Spirits  Scotland              Whisky        1.0  3700.000000
# ...        ...       ...                 ...        ...          ...
# 10798    White    France  Sauternes & Barsac        5.0    40.000000
# 10799  Spirits    Canada                 Gin        2.0    38.900002
# 10800    White    France            Burgundy        2.0    72.099998
# 10801    White   Germany             Germany        6.0    40.900002
# 10802    White    France  Sauternes & Barsac        4.0    49.900002
#
# [10803 rows x 8 columns]

# %%
df.to_csv('/Users/MacUser/hedonism-wines_app/full-stock-list_2024_03_28.csv',index=False)

# %%
conn.close()

# %%
pip install vega_datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting vega_datasets
#   Downloading vega_datasets-0.9.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas in /Users/MacUser/Library/Python/3.9/lib/python/site-packages (from vega_datasets) (2.2.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/MacUser/Library/Python/3.9/lib/python/site-packages (from pandas->vega_datasets) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/MacUser/Library/Python/3.9/lib/python/site-packages (from pandas->vega_datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/MacUser/Library/Python/3.9/lib/python/site-packages (from pandas->vega_datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/MacUser/Library/Python/3.9/lib/python/site-packages (from pandas->vega_datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/MacUser/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.8.2->pandas->vega_datasets) (1.16.0)
# Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.8/210.8 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: vega_datasets
# Successfully installed vega_datasets-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Objective: find which whiskies have been sold the day before today
# 1. Items where the availability has gone down
# 2. Codes that no longer exist, i.e. availability was = 1 and now they're no longer in the dataset after being sold

# %%
# 2. Identify duplicates and de-duplicate them by averaging availability
results = conn.execute("""   
                       WITH todays_items AS (             
                        SELECT code, title, url, price_gbp, availability, import_date 
                        FROM whisky_stocks_table
                        WHERE import_date = CURRENT_DATE()
                       ),
                       yesterdays_items AS (
                        SELECT code, title, url, price_gbp, availability, import_date  
                        FROM whisky_stocks_table
                        WHERE import_date = CURRENT_DATE() -1
                       )
                       SELECT CAST(CURRENT_DATE() AS DATE) AS import_date, a.code, 
						a.title, 
						a.url, 
						a.price_gbp,
						a.today_availability availability,
                        a.yesterday_availability - a.today_availability units_sold
                       FROM 
                       (
                       SELECT 
                       CAST (y.code AS STRING) ||'-'|| CAST (y.availability AS STRING) yesterday_code_availability,
                       CAST (t.code AS STRING) ||'-'|| CAST (t.availability AS STRING) today_code_availability,
                       y.code,
                       y.title,
                       y.url,
                       y.price_gbp,
                       y.availability yesterday_availability,
                       t.availability today_availability
                       FROM yesterdays_items y LEFT OUTER JOIN todays_items t
                       ON y.code = t.code
                       ) a
                       WHERE a.today_code_availability <> yesterday_code_availability
                       ORDER BY price_gbp DESC

            """).fetchdf()
	# Convert the results to a DataFrame
df = pd.DataFrame(results)
df.to_csv('/Users/MacUser/hedonism-wines_app/sales_2024_04_17.csv',index=False)
df
# Out:
#    import_date      code                                              title  \
# 0   2024-04-17  HED46498  A Trail of Smoke 42 Year Old House of Hazelwoo...
# 1   2024-04-17  HED21580                                    Macallan Oscuro
# 2   2024-04-17  HED46453  Bowmore 22 Year Old Aston Martin Master`s Sele...
# 3   2024-04-17  HED46709                  Macallan Rare Cask (2023 Release)
# 4   2024-04-17  HED21064  Speyside 18 Year Old (M) Cask Strength Collect...
# 5   2024-04-17   HED3161                               Yamazaki 12 Year Old
# 6   2024-04-17  HED21048  Caol Ila 16 Year Old Cask Strength Collection ...
# 7   2024-04-17  HED78927                            Glen Scotia 18 Year Old
# 8   2024-04-17  HED47122                           Kilchoman Batch Strength
# 9   2024-04-17  HED21147                   Port Charlotte Islay Barley 2014
# 10  2024-04-17  HED58719                     Edradour 12 Year Old Caledonia
# 11  2024-04-17  HED72835                          Ailsa Bay Sweet Smoke 1.2
# 12  2024-04-17   HED8633                               Edradour 10 Year Old
#
#                                                   url  price_gbp  \
# 0   https://hedonism.co.uk/product/a-trail-of-smok...     1900.0
# 1   https://hedonism.co.uk/product/macallan-oscuro...     1450.0
# 2   https://hedonism.co.uk/product/bowmore-22-year...      425.0
# 3   https://hedonism.co.uk/product/macallan-rare-c...      310.0
# 4   https://hedonism.co.uk/product/speyside-18-yea...      212.0
# 5   https://hedonism.co.uk/product/yamazaki-12-yea...      145.0
# 6   https://hedonism.co.uk/product/caol-ila-16-yea...      145.0
# 7   https://hedonism.co.uk/product/glen-scotia-18-...      128.0
# 8   https://hedonism.co.uk/product/kilchoman-batch...       73.0
# 9   https://hedonism.co.uk/product/port-charlotte-...       69.5
# 10  https://hedonism.co.uk/product/edradour-12-yea...       64.5
# 11  https://hedonism.co.uk/product/ailsa-bay-sweet...       59.0
# 12  https://hedonism.co.uk/product/edradour-10-yea...       46.0
#
#     availability  units_sold
# 0            2.0         1.0
# 1            1.0         1.0
# 2            3.0         2.0
# 3           12.0         6.0
# 4           35.0         1.0
# 5           34.0         2.0
# 6            4.0         2.0
# 7            3.0         2.0
# 8            3.0         3.0
# 9            2.0         1.0
# 10           4.0         2.0
# 11           6.0         1.0
# 12           3.0         3.0
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
